# %% [markdown]
# # **Python Programming Assignment**

# %% [markdown]
# **Exercise 1: Prime Numbers**
#
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def is_prime(n):
    """Check if a number is prime."""
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

# Test the function
number = int(input("Enter a number to check if it is prime: "))
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# Enter a number to check if it is prime: 17
# 17 is a prime number.

# %% [markdown]
# **Exercise 2: Product of Random Numbers**
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

def multiplication_quiz():
    # Generate two random numbers between 1 and 10
    num1 = random.randint(1, 10)
    num2 = random.randint(1, 10)

    # Calculate the correct product
    correct_product = num1 * num2

    # Ask the user to enter the product
    user_answer = int(input(f"What is the product of {num1} and {num2}? "))

    # Check if the user's answer is correct
    if user_answer == correct_product:
        print("Correct! Well done.")
    else:
        print(f"Incorrect. The correct answer is {correct_product}.")

# Run the multiplication quiz
multiplication_quiz()
# Out:
# What is the product of 8 and 7? 56
# Correct! Well done.

# %% [markdown]
# **Exercise 3: Squares of Even/Odd Numbers**
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
def print_squares(choice):
    """
    This function prints the squares of all even or odd numbers within the range of 100 to 200.
    The user chooses whether to print even or odd numbers.
    """
    if choice.lower() == 'even':
        print("Printing squares of even numbers between 100 and 200:")
        for num in range(100, 201):
            if num % 2 == 0:
                print(f"The square of {num} is {num ** 2}")
    elif choice.lower() == 'odd':
        print("Printing squares of odd numbers between 100 and 200:")
        for num in range(100, 201):
            if num % 2 != 0:
                print(f"The square of {num} is {num ** 2}")
    else:
        print("Invalid choice. Please choose 'even' or 'odd'.")

# Prompt the user to choose even or odd numbers
user_choice = input("Do you want to print the squares of 'even' or 'odd' numbers? ")

# Run the function with the user's choice
print_squares(user_choice)
# Out:
# Do you want to print the squares of 'even' or 'odd' numbers? even
# Printing squares of even numbers between 100 and 200:
# The square of 100 is 10000
# The square of 102 is 10404
# The square of 104 is 10816
# The square of 106 is 11236
# The square of 108 is 11664
# The square of 110 is 12100
# The square of 112 is 12544
# The square of 114 is 12996
# The square of 116 is 13456
# The square of 118 is 13924
# The square of 120 is 14400
# The square of 122 is 14884
# The square of 124 is 15376
# The square of 126 is 15876
# The square of 128 is 16384
# The square of 130 is 16900
# The square of 132 is 17424
# The square of 134 is 17956
# The square of 136 is 18496
# The square of 138 is 19044
# The square of 140 is 19600
# The square of 142 is 20164
# The square of 144 is 20736
# The square of 146 is 21316
# The square of 148 is 21904
# The square of 150 is 22500
# The square of 152 is 23104
# The square of 154 is 23716
# The square of 156 is 24336
# The square of 158 is 24964
# ...

# %% [markdown]
# **Exercise 4: Word counter**
#
# write a program to count the number of words in a given text.
# example:
# input_text = "This is a sample text. This text will be used to demonstrate the word counter."
# Expected output:
# 'This': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text.': 1

# %%
from collections import Counter

def count_words(text):
    """
    This is a sample text. This text will be used to demonstrate the word counter.
    """
    # Remove punctuation marks except for apostrophes (') and convert to lowercase
    cleaned_text = text.replace('.', '').replace(',', '').replace(';', '').replace(':', '').replace('!', '').replace('?', '').lower()

    # Split the text into words
    words = cleaned_text.split()

    # Count the occurrences of each word
    word_counts = Counter(words)

    # Print each word with its count
    for word, count in word_counts.items():
        print(f"'{word}': {count}")

# Example text
input_text = "This is a sample text. This text will be used to demonstrate the word counter."

# Count words in the example text
count_words(input_text)
# Out:
# 'this': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text': 2
# 'will': 1
# 'be': 1
# 'used': 1
# 'to': 1
# 'demonstrate': 1
# 'the': 1
# 'word': 1
# 'counter': 1

# %% [markdown]
# **Exercise 5: Check for Palindrome**
#
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.
#
# Example:
# Input: "racecar"
#
# Expected Output: True

# %%
def is_palindrome(input_string):
    """
    Check if a given string is a palindrome.

    Parameters:
    - input_string: A string to check for palindrome property.

    Returns:
    - True if the input_string is a palindrome, False otherwise.
    """
    # Normalize the string (convert to lowercase and remove spaces and punctuation)
    normalized_string = ''.join(char.lower() for char in input_string if char.isalnum())

    # Check if the normalized string is equal to its reverse
    return normalized_string == normalized_string[::-1]

# Function to get user input and call is_palindrome
def main():
    user_input = input("Enter a string to check if it is a palindrome: ")
    if is_palindrome(user_input):
        print(f"'{user_input}' is a palindrome.")
    else:
        print(f"'{user_input}' is not a palindrome.")

# Call the main function
if __name__ == "__main__":
    main()
# Out:
# Enter a string to check if it is a palindrome: A man, a plan, a canal, Panama
# 'A man, a plan, a canal, Panama' is a palindrome.
